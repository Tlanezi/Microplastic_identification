# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/nezim/PycharmProjects/percentile_calculator/percentile_results/data_set_percentiles_1.csv')

# %%
df
# Out:
#         MPs  nilre_filter_Red_component_percentile_50th  \
# 0        OM                                         3.4
# 1        PA                                       102.3
# 2       PA6                                         4.1
# 3        PE                                        42.1
# 4     PE100                                        63.5
# 5     PE102                                        63.4
# 6       pet                                       208.7
# 7   petmono                                         4.1
# 8       PLA                                       113.2
# 9        PP                                         0.0
# 10      PP1                                         6.2
# 11       PS                                       250.8
# 12      PVC                                        35.9
# 13      PSf                                         0.0
#
#     nilre_filter_ Red_ component_percentile_90th  \
# 0                                            9.9
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
